# %%
! cd /kaggle/input/wav2lip
! pip install -r /kaggle/input/wav2lip/Wav2Lip/Wav2Lip/requirements.txt
! pip install librosa==0.8.0
! mkdir "/kaggle/working/temp/"
! mkdir "/kaggle/working/temp/temp"

# %%
# !python /kaggle/input/wav2lip/Wav2Lip/Wav2Lip/inference.py --checkpoint_path "/kaggle/input/wav2lip/Wav2Lip/Wav2Lip/checkpoints/wav2lip_gan.pth" --face "/kaggle/input/wav2lip/test_image.png" --audio "/kaggle/input/wav2lip/test.wav" --outfile "/kaggle/working/output.mp4" --face_det_batch_size "1" --fps "60"
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Using cuda for inference.
# Number of frames available for inference: 1
# (80, 378)
# Length of mel chunks: 274
#   0%|                                                     | 0/3 [00:00<?, ?it/s]Downloading: "https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth" to /root/.cache/torch/hub/checkpoints/s3fd-619a316812.pth
#
#   0%|                                               | 0.00/85.7M [00:00<?, ?B/s]
#   0%|                                       | 32.0k/85.7M [00:00<06:52, 218kB/s]
#   0%|                                      | 96.0k/85.7M [00:01<20:01, 74.7kB/s]
#   0%|                                       | 112k/85.7M [00:01<18:43, 79.9kB/s]
# ...
